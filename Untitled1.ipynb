# %%
Pelicula = {
    "personajes" :{
        "personaje princpal" : "Djando",
        "personajes secundarios" :[ "Dr.king" , "hilda " ,"candy"]
          }
          "trama" : {
              "un desntista compra a un esclavo y este le ayuda reconocer a una pandilla de asesinos y al final rescatan la amada del esclavo"}
          "ambiemtacion" :{
              "esta ambientada en el viejo oeste antes de la gerra civil"
          }
          
}
# Out:
#   File "<ipython-input-5-f6f1db03ef09>", line 6
#     "trama" : {
#           ^
# SyntaxError: invalid syntax
